# %% [markdown]
# # 📈 角色二任務：連續變數與平均數分析
#
# ## 🎯 你的主要任務
# 1. **提出問題**：為你選擇的連續變數寫下一個明確的統計問題 。
# 2. **資料檢查**：說明變數定義、樣本數，並確保排除無效或缺失值 。
# 3. **探索性分析 (EDA)**：產出至少 **3 個**圖表/表格 (需包含直方圖、箱型圖、平均數/標準差等數據)，並檢查極端值。每個圖表下方需有文字解釋 。
# 4. **統計推論**：計算樣本平均數、標準差，建構信賴區間，並進行「單一樣本 t 檢定 (One-sample t-test)」 。
# 5. **結論解釋**：解釋推論結果，並說明是否與 EDA 觀察一致 。
#
# ## 💾 資料要怎麼處理
# * **讀取資料**：請讀取準備好的 `data/processed/yrbs_cleaned.csv`
# * **檢定基準值 ($\mu_0$)**：請對照說明文件 3.2 節，使用老師規定的基準值 (例如BMIPCT: µ0 = 65.0) 。

# %% [markdown]
# 📂 檔案讀取要正確：
#
# Colab 預設沒有我們的資料夾。請大家每次開啟 Colab 時，先在左側資料夾圖示中手動上傳 yrbs_cleaned.csv。
#
# 🖼️ 嚴禁螢幕截圖，圖表必須存檔：
#
# 我們不能用截圖產圖，畫出來的每一張圖，請用程式碼存檔 。
#
# ☁️ 下載雲端產物：
#
# Colab 關閉後，裡面存的圖片和表格就會消失。只要程式有存出圖片或 csv 表格，請立刻從 Colab 左側列表下載到自己的電腦裡。
#
# 🔄 每日手動備份到 GitHub ：
#
# 每次寫完一個段落準備關掉 Colab 前，請做這兩件事：點擊 Colab 左上角「檔案」 $\rightarrow$ 「下載 .ipynb」到我們的 GitHub 網頁，把 .ipynb 檔上傳到 notebooks/ 資料夾；把圖片檔上傳到 outputs/figures/ 資料夾。
