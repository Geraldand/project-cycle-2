# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# 1. 讀取資料 (請確認你的 csv 檔案路徑正確)
# 如果 csv 跟你的 .ipynb 檔案在同一個資料夾，直接寫 'yrbs_cleaned.csv' 即可
df = pd.read_csv('yrbs_cleaned.csv') 

# 2. 顯示資料前五行，確認有讀成功
print("--- 資料預覽 ---")
display(df.head())

# 3. 檢查 SadOrHopeless 變數的分布 (老師要求的 EDA 第一步)
print("\n--- 變數統計 ---")
counts = df['SadOrHopeless'].value_counts()
print(counts)

print("\n缺失值數量:", df['SadOrHopeless'].isnull().sum())
# Out:
# --- 資料預覽 ---
#    SadOrHopeless     BMIPCT  WhatIsYourSex  SadOrHopeless_Recoded
# 0            2.0  66.531824            2.0                    0.0
# 1            1.0  98.174319            1.0                    1.0
# 2            2.0  33.075531            1.0                    0.0
# 3            2.0  45.688334            1.0                    0.0
# 4            2.0  62.390331            1.0                    0.0
# --- 變數統計 ---
# SadOrHopeless
# 2.0    9060
# 1.0    3842
# Name: count, dtype: int64
#
# 缺失值數量: 0
